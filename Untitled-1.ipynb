# %%
acs_part1.dtypes
# Out:
# Reservoir\tFish\tMercury\tElevation\tDrainage Area\tSurface Area\tMax Depth\tRF\tFR\tDam\tRT\tRS    object
# dtype: object

# %%
acs_part2.dtypes
# Out:
# Reservoir\t\t\tLATITUDE_DEGREES\tLATITUDE_MINUTES\tLATITUDE_SECONDS\tLONGITUDE_DEGREES\tLONGITUDE_MINUTES\tLONGITUDE_SECONDS    object
# dtype: object

# %%
acs_part2 = pd.read_csv('fairfield_loc.csv',encoding='latin-1')
acs_part2
# Out:
#     Reservoir\tFish\tMercury\tElevation\tDrainage Area\tSurface Area\tMax Depth\tRF\tFR\tDam\tRT\tRS  \
# 0    Abilene\t3\t0.053\t196\t6\t74\t36\t0.44\t1.1\t...
# 1    Abraham Lake\t4\t0.35\t345\t15\t360\t80\t0.51\...
# 2    Academy\t5\t0.54\t487\t1\t175\t10\t0.57\t1.5\t...
# 3    Acadia\t5\t0.29\t165\t131\t5543\t100\t0.51\t1....
# 4    Acadia Valley\t5\t0.91\t1273\t65\t700\t106\t0....
# ..                                                 ...
# 117  Yak Lakes\t3\t0.43\t341\t4\t467\t55\t0.58\t0.5...
# 118  Yellowstone Creek\t3\t0.41\t87\t106\t532\t57\t...
# 119  Zama Lake\t3\t0.36\t1503\t6\t211\t58\t0.56\t1....
# 120  Zephyr Creek\t5\t0.37\t1700\t4\t70\t58\t0.56\t...
# 121  Zig Zag Lake\t5\t0.48\t846\t92\t422\t6\t0.58\t...
#
#     Reservoir\t\t\tLATITUDE_DEGREES\tLATITUDE_MINUTES\tLATITUDE_SECONDS\tLONGITUDE_DEGREES\tLONGITUDE_MINUTES\tLONGITUDE_SECONDS
# 0                  Abilene\t\t\t44\t57\t44\t68\t 5\t 7
# 1             Abraham Lake\t\t\t45\t37\t50\t69\t12\t30
# 2                  Academy\t\t\t44\t25\t13\t70\t19\t22
# 3                   Acadia\t\t\t43\t37\t 0\t70\t59\t 4
# 4            Acadia Valley\t\t\t45\t30\t32\t67\t50\t 2
# ..                                                 ...
# 117              Yak Lakes\t\t44\t58\t 9\t69\t19\t33\t
# 118      Yellowstone Creek\t\t\t44\t27\t48\t68\t40\t33
# 119              Zama Lake\t\t\t45\t38\t12\t70\t20\t40
# 120           Zephyr Creek\t\t\t44\t36\t39\t69\t46\t53
# 121           Zig Zag Lake\t\t\t44\t47\t25\t71\t 0\t47
#
# [122 rows x 2 columns]

# %%
acs_part1 = pd.read_csv('fairfield.csv',encoding='latin-1')
acs_part1
# Out:
#              Reservoir  Fish  Mercury  Elevation  Drainage Area  Surface Area  \
# 0              Abilene     3    0.053        196            6.0            74
# 1         Abraham Lake     4    0.350        345           15.0           360
# 2              Academy     5    0.540        487            1.0           175
# 3               Acadia     5    0.290        165          131.0          5543
# 4        Acadia Valley     5    0.910       1273           65.0           700
# ..                 ...   ...      ...        ...            ...           ...
# 117          Yak Lakes     3    0.430        341            4.0           467
# 118  Yellowstone Creek     3    0.410         87          106.0           532
# 119          Zama Lake     3    0.360       1503            6.0           211
# 120       Zephyr Creek     5    0.370       1700            4.0            70
# 121       Zig Zag Lake     5    0.480        846           92.0           422
#
#      Max Depth    RF    FR  Dam   RT   RS
# 0         36.0  0.44   1.1  1.0  2.0  0.0
# 1         80.0  0.51   1.7  0.0  3.0  1.0
# 2         10.0  0.57   1.5  0.0  3.0  0.0
# 3        100.0  0.51   1.1  0.0  2.0  1.0
# 4        106.0  0.62   4.3  0.0  1.0  1.0
# ..         ...   ...   ...  ...  ...  ...
# 117       55.0  0.58   0.5  1.0  1.0  1.0
# 118       57.0  0.60  14.2  0.0  3.0  1.0
# 119       58.0  0.56   1.8  1.0  1.0  1.0
# 120       58.0  0.56   3.8  1.0  3.0  1.0
# 121        6.0  0.58  45.2  1.0  2.0  0.0
#
# [122 rows x 12 columns]

# %%
import pandas as pd
acs_part1 = pd.read_csv('fairfield.csv',encoding='latin-1')
acs_part1

acs_part2 = pd.read_csv('fairfield_loc.csv',encoding='latin-1')
acs_part2

pd.merge(
    acs_part1, acs_part2,
    left_index=True, right_index=True,
)
# Out:
#            Reservoir_x  Fish  Mercury  Elevation  Drainage Area  Surface Area  \
# 0              Abilene     3    0.053        196            6.0            74
# 1         Abraham Lake     4    0.350        345           15.0           360
# 2              Academy     5    0.540        487            1.0           175
# 3               Acadia     5    0.290        165          131.0          5543
# 4        Acadia Valley     5    0.910       1273           65.0           700
# ..                 ...   ...      ...        ...            ...           ...
# 117          Yak Lakes     3    0.430        341            4.0           467
# 118  Yellowstone Creek     3    0.410         87          106.0           532
# 119          Zama Lake     3    0.360       1503            6.0           211
# 120       Zephyr Creek     5    0.370       1700            4.0            70
# 121       Zig Zag Lake     5    0.480        846           92.0           422
#
#      Max Depth    RF    FR  Dam   RT   RS        Reservoir_y  \
# 0         36.0  0.44   1.1  1.0  2.0  0.0            Abilene
# 1         80.0  0.51   1.7  0.0  3.0  1.0       Abraham Lake
# 2         10.0  0.57   1.5  0.0  3.0  0.0            Academy
# 3        100.0  0.51   1.1  0.0  2.0  1.0             Acadia
# 4        106.0  0.62   4.3  0.0  1.0  1.0      Acadia Valley
# ..         ...   ...   ...  ...  ...  ...                ...
# 117       55.0  0.58   0.5  1.0  1.0  1.0          Yak Lakes
# 118       57.0  0.60  14.2  0.0  3.0  1.0  Yellowstone Creek
# 119       58.0  0.56   1.8  1.0  1.0  1.0          Zama Lake
# 120       58.0  0.56   3.8  1.0  3.0  1.0       Zephyr Creek
# 121        6.0  0.58  45.2  1.0  2.0  0.0       Zig Zag Lake
#
#      LATITUDE_DEGREES  LATITUDE_MINUTES  LATITUDE_SECONDS  LONGITUDE_DEGREES  \
# 0                  44                57                44                 68
# 1                  45                37                50                 69
# 2                  44                25                13                 70
# 3                  43                37                 0                 70
# 4                  45                30                32                 67
# ..                ...               ...               ...                ...
# 117                58                 9                69                 19
# 118                44                27                48                 68
# 119                45                38                12                 70
# 120                44                36                39                 69
# 121                44                47                25                 71
#
#      LONGITUDE_MINUTES  LONGITUDE_SECONDS
# 0                  5.0                7.0
# 1                 12.0               30.0
# 2                 19.0               22.0
# 3                 59.0                4.0
# 4                 50.0                2.0
# ..                 ...                ...
# 117               33.0                NaN
# 118               40.0               33.0
# 119               20.0               40.0
# 120               46.0               53.0
# 121                0.0               47.0
#
# [122 rows x 19 columns]

# %%
import pandas as pd

df=pd.read_csv('Fairfield.csv',encoding='latin-1')


#FINDING MAX AND MIN
p=df['Mercury'].max()
q=df['Mercury'].min()
print(p)
print(q)
# Out:
# 2.5
# 0.025

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('fairfield.csv',encoding='latin-1', usecols=['Mercury','Fish','Elevation'])
print(df.describe())
plt.hist(df['Mercury'])
# Out:
#              Fish     Mercury    Elevation
# count  122.000000  122.000000   122.000000
# mean     4.262295    0.492287   569.049180
# std      1.096978    0.353569   431.745292
# min      1.000000    0.025000    15.000000
# 25%      4.000000    0.250000   251.000000
# 50%      5.000000    0.410000   416.500000
# 75%      5.000000    0.667500   840.500000
# max      6.000000    2.500000  1700.000000
# (array([35., 42., 21., 16.,  6.,  0.,  0.,  1.,  0.,  1.]),
#  array([0.025 , 0.2725, 0.52  , 0.7675, 1.015 , 1.2625, 1.51  , 1.7575,
#         2.005 , 2.2525, 2.5   ]),
#  <BarContainer object of 10 artists>)

# %%
df = pd.read_csv('fairfield.csv',encoding='latin-1', usecols=['Fish'])
print(df.describe())
plt.hist(df['Fish'])
# Out:
#              Fish
# count  122.000000
# mean     4.262295
# std      1.096978
# min      1.000000
# 25%      4.000000
# 50%      5.000000
# 75%      5.000000
# max      6.000000
# (array([ 2.,  0., 10.,  0., 18.,  0., 17.,  0., 74.,  1.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
import pandas as pd
  
  
# Initialize the lists for X and Y
data = pd.read_csv('fairfield.csv',encoding='latin-1')
  
df = pd.DataFrame(data)
  
X = list(df.iloc[:, 0])
Y = list(df.iloc[:, 2])
  
# Plot the data using bar() method
plt.bar(X, Y, color='g')
plt.title("Mercury level in reservoir")
plt.xlabel("Reservoir")
plt.ylabel("Mercury")
  
# Show the plot
plt.show()

# %%
#Correlation 

df.corr()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15620\1008123944.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                    Fish   Mercury  Elevation  Drainage Area  Surface Area  \
# Fish           1.000000  0.081670  -0.063021      -0.000293     -0.048742
# Mercury        0.081670  1.000000  -0.254471      -0.041337     -0.046194
# Elevation     -0.063021 -0.254471   1.000000       0.077457     -0.080914
# Drainage Area -0.000293 -0.041337   0.077457       1.000000      0.660598
# Surface Area  -0.048742 -0.046194  -0.080914       0.660598      1.000000
# Max Depth     -0.116017 -0.067808   0.061609       0.283874      0.378651
# RF            -0.013405 -0.068569   0.215585      -0.049789     -0.019381
# FR            -0.162004 -0.066108   0.079174       0.081035     -0.096310
# Dam           -0.014842 -0.112865   0.225940      -0.108306     -0.250241
# RT             0.148011 -0.010885  -0.199279      -0.126083     -0.178947
# RS            -0.126840  0.098325   0.029239      -0.075925     -0.052036
#
#                Max Depth        RF        FR       Dam        RT        RS
# Fish           -0.116017 -0.013405 -0.162004 -0.014842  0.148011 -0.126840
# Mercury        -0.067808 -0.068569 -0.066108 -0.112865 -0.010885  0.098325
# Elevation       0.061609  0.215585  0.079174  0.225940 -0.199279  0.029239
# Drainage Area   0.283874 -0.049789  0.081035 -0.108306 -0.126083 -0.075925
# Surface Area    0.378651 -0.019381 -0.096310 -0.250241 -0.178947 -0.052036
# Max Depth       1.000000  0.018637 -0.274658 -0.192159 -0.420850  0.564370
# RF              0.018637  1.000000  0.045905 -0.104912 -0.006998 -0.049278
# FR             -0.274658  0.045905  1.000000  0.145329 -0.028414 -0.113716
# Dam            -0.192159 -0.104912  0.145329  1.000000 -0.003058  0.011842
# RT             -0.420850 -0.006998 -0.028414 -0.003058  1.000000 -0.228679
# RS              0.564370 -0.049278 -0.113716  0.011842 -0.228679  1.000000

# %%
#Correlation plot
import seaborn as sns

sns.heatmap(df.corr())
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15620\3770992865.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %%
#Find null values

df.isnull().sum()
# Out:
# Reservoir        0
# Fish             0
# Mercury          0
# Elevation        0
# Drainage Area    3
# Surface Area     0
# Max Depth        1
# RF               7
# FR               7
# Dam              3
# RT               1
# RS               2
# dtype: int64

# %%
#Datatypes

df.dtypes
# Out:
# Reservoir         object
# Fish               int64
# Mercury          float64
# Elevation          int64
# Drainage Area    float64
# Surface Area       int64
# Max Depth        float64
# RF               float64
# FR               float64
# Dam              float64
# RT               float64
# RS               float64
# dtype: object

# %%
#Filter data

df[df['Mercury']==0.025].head()
# Out:
#       Reservoir  Fish  Mercury  Elevation  Drainage Area  Surface Area  \
# 62  Plover Lake     2    0.025       1494            1.0            47
#
#     Max Depth    RF   FR  Dam   RT   RS
# 62       26.0  0.69  0.8  1.0  2.0  0.0
